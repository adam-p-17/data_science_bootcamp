# %% [markdown]
# # Zadanie 6*

# %%
import matplotlib.pyplot as plt

# %%
wzrost = [180, 190, 170, 160]
waga = [80, 90, 70, 60]

# %%
plt.scatter(x = wzrost, y = waga, color = 'blue')
plt.xlabel('Wzrost')
plt.ylabel('Waga')
plt.title('Zależność wagi od wzrostu')
plt.show()
